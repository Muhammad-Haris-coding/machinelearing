# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('pca_dataset.csv')
df.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Target
# 0         10         12         30       0
# 1         11         13         29       0
# 2         12         14         28       0
# 3         13         15         31       0
# 4         14         16         35       0

# %%
import plotly.express as px
fig=px.scatter_3d(df,x='Feature_1',y='Feature_2',z='Feature_3')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 import plotly.express as px
#       2 fig=px.scatter_3d(df,x='Feature_1',y='Feature_2',z='Feature_3')
# ----> 3 fig.show()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
# ...

# %%
# Step 1: Standardize the Data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df=scaler.fit_transform(df[['Feature_1','Feature_2','Feature_3']])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 from sklearn.preprocessing import StandardScaler
#       3 scaler=StandardScaler()
# ----> 4 df=scaler.fit_transform(df[['Feature_1','Feature_2','Feature_3']])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#Step 2: Covariance Matrix
cov_matrix=np.cov(df[['Feature_1']],df[['Feature_2']],df[['Feature_3']])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 #Step 2: Covariance Matrix
# ----> 2 cov_matrix=np.cov(df[['Feature_1']],df[['Feature_2']],df[['Feature_3']])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#Step 3: Calculate Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
print("Eigenvalues:", eigenvalues)
print("Eigenvectors shape:", eigenvectors.shape)

# %%
#Step 6: Visualize PCA Results (2D)
# Reload target values for coloring
df_original = pd.read_csv('pca_dataset.csv')
pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2'])
pca_df['Target'] = df_original['Target'].values
fig = px.scatter(pca_df, x='PC1', y='PC2', color='Target', title='PCA Visualization (2D)')
fig.show()

# %%
#Step 5: Transform data using principal components
pca_data = df @ top_eigenvectors
print("PCA transformed data shape:", pca_data.shape)
print(pca_data[:5])

# %%
#Step 4: Sort eigenvalues and select top 2 principal components
sorted_indices = np.argsort(eigenvalues)[::-1]
top_eigenvalues = eigenvalues[sorted_indices[:2]]
top_eigenvectors = eigenvectors[:, sorted_indices[:2]]
print("Top 2 Eigenvalues:", top_eigenvalues)
print("Variance Explained:", top_eigenvalues / np.sum(eigenvalues))
