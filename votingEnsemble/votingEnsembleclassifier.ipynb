# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
df=pd.DataFrame(load_iris().data, columns=load_iris().feature_names)
df['target']=pd.DataFrame(load_iris().target, columns=['target'])

# %%
df=df[df['target']!=0]

# %%
df.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
x=df.iloc[:,1:3]
x.shape
# Out:
# (100, 2)

# %%
y=df['target']

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
lr=LogisticRegression()
rf=RandomForestClassifier()
knn=KNeighborsClassifier()

# %%
estimators=[('lr',lr),('rf',rf),('knn',knn)]

for estimater in estimators:
    score=cross_val_score(estimater[1],x,y, cv=5)
    print('estimater: ', estimater[0], 'score: ', score.mean())
# Out:
# estimater:  lr score:  0.93
# estimater:  rf score:  0.9100000000000001
# estimater:  knn score:  0.93

# %% [markdown]
# # hard voting

# %%
from sklearn.ensemble import VotingClassifier
vc1=VotingClassifier(estimators=estimators, voting='hard')
score=cross_val_score(vc1,x,y, cv=5)
print("voting classifier score :", score.mean())
# Out:
# voting classifier score : 0.93

# %% [markdown]
# # soft voting

# %%
vc2=VotingClassifier(estimators=estimators , voting='soft')
score=cross_val_score(vc2,x,y,cv=5)
print("voting classifier score :", score.mean())
# Out:
# voting classifier score : 0.93
