# %%
from sklearn.datasets import load_diabetes
import pandas as pd
import numpy as np

# %%
x,y=load_diabetes(return_X_y=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()
svr=SVR()

estimators=[('lr',lr),('dt',dt),('svr',svr)]

# %%
for estimator in estimators:
    score=cross_val_score(estimator[1],x,y,cv=5)
    print(estimator[0], "score :", score.mean())
# Out:
# lr score : 0.4823164359086423
# dt score : -0.1757643112824082
# svr score : 0.14680869160894452

# %%
from sklearn.ensemble import VotingRegressor
vc1=VotingRegressor(estimators=estimators )
score=cross_val_score(vc1,x,y, cv=5)
print("voting regressor score :", score.mean())
# Out:
# voting regressor score : 0.3841760879782491
