# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('CGPA_packege.csv')
print(df.head())
# Out:
#    CGPA  Package_PKR
# 0  2.10       320000
# 1  2.12       325000
# 2  2.14       330000
# 3  2.15       335000
# 4  2.16       340000

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       320000
# 1       325000
# 2       330000
# 3       335000
# 4       340000
#         ...
# 110    1500000
# 111    1520000
# 112    1540000
# 113    1560000
# 114    1600000
# Name: Package_PKR, Length: 115, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
from sklearn.metrics import accuracy_score,r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9049003126900879

# %%
y_test
# Out:
# 35      495000
# 83      960000
# 24      440000
# 14      390000
# 2       330000
# 78      860000
# 13      385000
# 48      560000
# 111    1520000
# 25      445000
# 54      590000
# 105    1400000
# 64      690000
# 74      790000
# 29      465000
# 28      460000
# 27      455000
# 88     1060000
# 36      500000
# 56      610000
# 30      470000
# 80      900000
# 21      425000
# Name: Package_PKR, dtype: int64

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([520717.63030718])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x_train,lr.predict(x_train),color='green')
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')
