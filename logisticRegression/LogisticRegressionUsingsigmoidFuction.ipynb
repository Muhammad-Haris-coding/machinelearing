# %%
from sklearn.datasets import make_classification
import numpy as np
x,y=make_classification(  n_samples=100,
    n_features=2,
    n_informative=1,
    n_redundant=0,
    n_repeated=0,
    n_classes=2,
    n_clusters_per_class=1,
    weights=None,
    flip_y=0.01,
    class_sep=20,
    hypercube=False,
    shift=0.0,
    scale=1.0,
    shuffle=True,
    random_state=41)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=100)

# %%
def sigmoid(x,y):
    x=np.insert(x,0,1,axis=1)
    w=np.ones(x.shape[1])
    lr=0.01
    for i in range(100000):
        j=np.random.randint(0,100)
        y_hat=sigmoidfuction(np.dot(x[j],w))
        w=w +lr*(y[j]-y_hat)*x[j]

    return w[0], w[1:]

# %%
def sigmoidfuction(z):
    return 1/(1+np.exp(-z))

# %%
intercept_ , coef_=sigmoid(x,y)

# %%
print(intercept_)
print(coef_)
# Out:
# 4.921372214203035
# [4.20995057 0.15213482]

# %%
m=-(coef_[0]/coef_[1])
b=-(intercept_/coef_[1])
x_input=np.linspace(-3,3,100)
y_input=m*x_input +b

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1],c=y,cmap="winter",s=100)
plt.plot(x_input ,y_input ,c='red')
