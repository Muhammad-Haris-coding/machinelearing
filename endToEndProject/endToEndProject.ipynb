# %%
import pandas as pd

# %%
df=pd.read_csv("D:\ML_campusX\endToEndProject\student_placement_dataset.csv")

# %%
#df['CGPA'].max()
df['IQ'].max()
# Out:
# 143

# %%
import matplotlib.pyplot as plt
plt.scatter(df['CGPA'],df['IQ'],c=df['Placement'])

# %%
# input and output separation
x=df.iloc[:,0:2]

# %%
y=df.iloc[:,-1]

# %%
x
# Out:
#     CGPA   IQ
# 0   6.80  116
# 1   9.56  123
# 2   8.51  133
# 3   7.87  136
# 4   5.75  116
# ..   ...  ...
# 95  7.37  128
# 96  7.51  110
# 97  7.05  116
# 98  5.12   90
# 99  5.52  116
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0
#      ..
# 95    0
# 96    1
# 97    0
# 98    0
# 99    0
# Name: Placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train.head()
# Out:
#     CGPA   IQ
# 91  8.42   85
# 90  5.57  117
# 16  6.46  116
# 84  6.49   86
# 0   6.80  116

# %%
y_train.head()
# Out:
# 91    0
# 90    0
# 16    0
# 84    0
# 0     0
# Name: Placement, dtype: int64

# %%
#scaling the values
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 0.83561551, -1.82102772],
#        [-1.18089948,  0.03808601],
#        [-0.55118076, -0.02001129],
#        [-0.52995429, -1.76293042],
#        [-0.31061406, -0.02001129],
#        [ 1.54316463,  0.03808601],
#        [-0.96155925, -1.12386007],
#        [ 0.42523702, -0.25240051],
#        [ 0.49599193, -0.60098433],
#        [-0.5228788 , -1.12386007],
#        [-1.32948479,  0.27047523],
#        [-1.28703185,  1.08383748],
#        [ 0.66580372,  1.14193479],
#        [-0.96863474,  0.21237792],
#        [-0.03466991,  0.73525366],
#        [-0.70684157,  1.43242131],
#        [ 1.18231458,  0.38666984],
#        [-1.0040122 ,  0.67715636],
#        [-0.36721799,  0.96764288],
#        [-0.66438862,  1.54861592],
#        [ 1.76958034,  0.96764288],
#        [-0.09127384,  0.38666984],
#        [-1.36486225, -1.76293042],
#        [-0.86250237, -0.19430321],
#        [ 1.45825873, -1.35624929],
#        [ 0.25542523, -0.48478973],
#        [ 0.31910465, -1.76293042],
#        [ 1.1610881 ,  1.49051861],
#        [-1.11014457, -0.25240051],
#        [-1.18797497,  1.374324  ],
#        [-0.95448376,  0.38666984],
#        [ 1.63514601, -0.1362059 ],
#        [ 1.69882543, -1.24005468],
#        [-1.05354064, -1.64673581],
#        [-0.59363371,  1.08383748],
#        [-0.90495532,  1.20003209],
#        [-1.562976  , -1.18195738],
#        [ 1.04788024, -1.41434659],
#        [ 1.0832577 ,  1.43242131],
#        [ 1.03372926,  1.20003209],
#        [ 1.23184301,  1.2581294 ],
#        [ 0.26957621, -1.70483311],
#        [-0.48042585, -0.48478973],
#        [ 1.03372926,  0.96764288],
#        [ 0.44646349,  0.27047523],
#        [ 0.44646349,  1.14193479],
#        [ 0.48184095,  0.67715636],
#        [-1.25165439, -0.25240051],
#        [ 0.18467032,  0.50286444],
#        [ 0.89221944, -1.70483311],
#        [ 0.1988213 , -1.4724439 ],
#        [ 0.99835181, -0.77527625],
#        [ 1.35920186,  0.27047523],
#        [ 1.50071168, -0.31049781],
#        [ 1.60684405, -0.31049781],
#        [-0.59363371, -1.76293042],
#        [ 1.71297641, -1.00766546],
#        [ 1.13986163,  1.14193479],
#        [-1.32948479,  0.96764288],
#        [ 1.42995677,  0.27047523],
#        [-0.55118076,  1.3162267 ],
#        [-0.26108562, -1.00766546],
#        [ 0.73655863, -0.42669242],
#        [-1.51344756,  0.73525366],
#        [ 0.46061448, -0.54288703],
#        [ 1.34505087, -0.89147086],
#        [ 1.245994  ,  0.61905905],
#        [ 0.81438903, -1.76293042],
#        [-1.42854167,  0.67715636],
#        [ 0.89221944,  1.2581294 ],
#        [-0.9191063 ,  0.56096175],
#        [ 0.16344385, -1.5305412 ],
#        [-1.21627693, -0.02001129],
#        [-1.05354064, -0.02001129],
#        [-1.38608872, -0.1362059 ],
#        [-1.49929658, -1.5305412 ],
#        [-0.48042585, -0.25240051],
#        [-1.10306907,  0.50286444],
#        [-0.62901117, -0.02001129],
#        [ 0.89929493,  0.96764288],
#        [-0.13372678, -0.02001129],
#        [-1.36486225, -0.71717894],
#        [ 0.82146453,  0.38666984],
#        [-1.42854167, -0.25240051],
#        [-0.1195758 ,  1.54861592],
#        [ 0.09268893,  0.67715636],
#        [ 0.19174581, -0.36859512],
#        [ 0.53136939,  1.54861592],
#        [-0.91203081,  1.14193479],
#        [ 0.02193402, -0.02001129]])

# %%
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[ 1.51630715, -1.5145095 ],
#        [-0.48097915, -0.10817925],
#        [ 1.45516573,  0.27044813],
#        [-0.02581527, -1.78495763],
#        [-0.44701169,  0.432717  ],
#        [-1.24185012, -0.05408963],
#        [-1.52717673,  1.24406138],
#        [ 0.43614211, -0.59498588],
#        [-0.56250104,  0.81134438],
#        [ 0.87771901,  1.298151  ]])

# %%
#model building
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 50    0
# 63    0
# 1     1
# 41    0
# 23    0
# 40    0
# 42    0
# 87    0
# 82    0
# 70    1
# Name: Placement, dtype: int64

# %%
#accuracy check
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
pred=clf.predict([[9,150]])

# %%
print(pred)
# Out:
# [1]

# %%
import pickle
pickle.dump(clf,open('logictic_model.pkl','wb'))
